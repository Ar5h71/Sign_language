# %%
import pandas as pd
import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import csv
X_train = pd.read_csv("sign_mnist_train.csv") 
X_test = pd.read_csv("sign_mnist_test.csv") 

y_train=X_train['label']
y_test=X_test['label']

    
X_train = np.array(X_train.iloc[:,1:])
X_train = np.array([np.reshape(i, (28,28)) for i in X_train])
X_test = np.array(X_test.iloc[:,1:])
X_test = np.array([np.reshape(i, (28,28)) for i in X_test])
num_classes = 26
y_train = np.array(y_train).reshape(-1)
y_test = np.array(y_test).reshape(-1)
y_train = np.eye(num_classes)[y_train]
y_test = np.eye(num_classes)[y_test]
X_train = X_train.reshape((27455, 28, 28, 1))
X_test = X_test.reshape((7172, 28, 28, 1))







classifier = Sequential()
classifier.add(Conv2D(filters=8, kernel_size=(3,3),strides=(1,1),padding='same',input_shape=(28,28,1),activation='relu', data_format='channels_last'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Conv2D(filters=16, kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
classifier.add(Dropout(0.5))
classifier.add(MaxPooling2D(pool_size=(4,4)))
classifier.add(Dense(128, activation='relu'))
classifier.add(Flatten())
classifier.add(Dense(26, activation='softmax'))


classifier.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train, y_train, epochs=50, batch_size=100)

accuracy = classifier.evaluate(x=X_test,y=y_test,batch_size=32)
print("Accuracy: ",accuracy[1])
# Out:
# WARNING:tensorflow:From D:\Users\ishandixit\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From D:\Users\ishandixit\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From D:\Users\ishandixit\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Epoch 1/50
# 27455/27455 [==============================] - 9s 327us/step - loss: 4.7306 - accuracy: 0.0460
# Epoch 2/50
# 27455/27455 [==============================] - 8s 285us/step - loss: 3.2376 - accuracy: 0.0450
# Epoch 3/50
# 27455/27455 [==============================] - 7s 273us/step - loss: 3.2242 - accuracy: 0.0471
# Epoch 4/50
# 27455/27455 [==============================] - 8s 285us/step - loss: 3.2101 - accuracy: 0.0475
# Epoch 5/50
# 27455/27455 [==============================] - 7s 269us/step - loss: 3.1938 - accuracy: 0.0552
# Epoch 6/50
# 27455/27455 [==============================] - 8s 278us/step - loss: 3.1805 - accuracy: 0.0690
# Epoch 7/50
# 27455/27455 [==============================] - 7s 268us/step - loss: 3.1636 - accuracy: 0.0689
# Epoch 8/50
# 27455/27455 [==============================] - 8s 281us/step - loss: 3.1674 - accuracy: 0.0625
# Epoch 9/50
# 27455/27455 [==============================] - 7s 270us/step - loss: 3.1231 - accuracy: 0.0875
# Epoch 10/50
# 27455/27455 [==============================] - 8s 274us/step - loss: 2.8172 - accuracy: 0.1705
# Epoch 11/50
# 27455/27455 [==============================] - 7s 269us/step - loss: 2.1461 - accuracy: 0.3611
# Epoch 12/50
# 27455/27455 [==============================] - 8s 286us/step - loss: 2.8215 - accuracy: 0.1580
# Epoch 13/50
# 27455/27455 [==============================] - 8s 275us/step - loss: 1.5559 - accuracy: 0.51500s - loss: 1.5672 - ac
# Epoch 14/50
# 27455/27455 [==============================] - 8s 295us/step - loss: 1.0657 - accuracy: 0.65540s - loss: 1.0715 - accuracy
# Epoch 15/50
# 27455/27455 [==============================] - 8s 292us/step - loss: 0.8934 - accuracy: 0.7109
# Epoch 16/50
# 27455/27455 [==============================] - 8s 287us/step - loss: 0.7079 - accuracy: 0.7685
# Epoch 17/50
# 27455/27455 [==============================] - 8s 280us/step - loss: 0.6164 - accuracy: 0.7924
# Epoch 18/50
# 27455/27455 [==============================] - 7s 272us/step - loss: 0.5441 - accuracy: 0.8171
# Epoch 19/50
# 27455/27455 [==============================] - 8s 286us/step - loss: 0.5177 - accuracy: 0.8254
# Epoch 20/50
# 27455/27455 [==============================] - 8s 288us/step - loss: 0.4482 - accuracy: 0.84730s - loss: 0.4494 - accuracy
# Epoch 21/50
# 27455/27455 [==============================] - 8s 280us/step - loss: 0.4218 - accuracy: 0.8577
# Epoch 22/50
# 27455/27455 [==============================] - 8s 296us/step - loss: 0.3915 - accuracy: 0.8662
# Epoch 23/50
# 27455/27455 [==============================] - 9s 321us/step - loss: 0.3638 - accuracy: 0.8763
# Epoch 24/50
# 27455/27455 [==============================] - 8s 303us/step - loss: 0.3652 - accuracy: 0.8746
# Epoch 25/50
# 27455/27455 [==============================] - 8s 277us/step - loss: 0.3501 - accuracy: 0.8808TA: 0s
# Epoch 26/50
# 27455/27455 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.88 - 8s 279us/step - loss: 0.3300 - accuracy: 0.8874
# Epoch 27/50
# 27455/27455 [==============================] - 7s 269us/step - loss: 0.3138 - accuracy: 0.8919
# Epoch 28/50
# 27455/27455 [==============================] - 7s 262us/step - loss: 0.2994 - accuracy: 0.8997
# Epoch 29/50
# 27455/27455 [==============================] - 7s 267us/step - loss: 0.2925 - accuracy: 0.9003
# Epoch 30/50
# 27455/27455 [==============================] - 7s 272us/step - loss: 0.2754 - accuracy: 0.9081
# Epoch 31/50
# 27455/27455 [==============================] - 8s 279us/step - loss: 0.2710 - accuracy: 0.9083
# Epoch 32/50
# 27455/27455 [==============================] - 8s 274us/step - loss: 0.2716 - accuracy: 0.9083
# Epoch 33/50
# 27455/27455 [==============================] - 8s 283us/step - loss: 0.2602 - accuracy: 0.9128
# Epoch 34/50
# 27455/27455 [==============================] - 8s 293us/step - loss: 0.2613 - accuracy: 0.9116
# Epoch 35/50
# 27455/27455 [==============================] - 9s 322us/step - loss: 0.2452 - accuracy: 0.9162
# Epoch 36/50
# 27455/27455 [==============================] - 8s 280us/step - loss: 0.2280 - accuracy: 0.9227
# Epoch 37/50
# 27455/27455 [==============================] - 8s 299us/step - loss: 0.2418 - accuracy: 0.9188
# Epoch 38/50
# 27455/27455 [==============================] - 8s 285us/step - loss: 0.2523 - accuracy: 0.9157
# Epoch 39/50
# 27455/27455 [==============================] - 8s 290us/step - loss: 0.2142 - accuracy: 0.9272
# Epoch 40/50
# 27455/27455 [==============================] - 8s 285us/step - loss: 0.2269 - accuracy: 0.9236
# Epoch 41/50
# 27455/27455 [==============================] - 8s 291us/step - loss: 0.2140 - accuracy: 0.9269
# Epoch 42/50
# 27455/27455 [==============================] - 8s 274us/step - loss: 0.2124 - accuracy: 0.9294
# Epoch 43/50
# 27455/27455 [==============================] - 8s 287us/step - loss: 0.2302 - accuracy: 0.9217
# Epoch 44/50
# 27455/27455 [==============================] - 8s 285us/step - loss: 0.2026 - accuracy: 0.9315
# Epoch 45/50
# 27455/27455 [==============================] - 8s 290us/step - loss: 0.2037 - accuracy: 0.9315
# Epoch 46/50
# 27455/27455 [==============================] - 8s 280us/step - loss: 0.2091 - accuracy: 0.9299
# Epoch 47/50
# 27455/27455 [==============================] - 8s 294us/step - loss: 0.2210 - accuracy: 0.9270
# Epoch 48/50
# 27455/27455 [==============================] - 8s 277us/step - loss: 0.1935 - accuracy: 0.9349
# Epoch 49/50
# 27455/27455 [==============================] - 7s 268us/step - loss: 0.1957 - accuracy: 0.9332
# Epoch 50/50
# 27455/27455 [==============================] - 7s 262us/step - loss: 0.1895 - accuracy: 0.9356
# 7172/7172 [==============================] - 1s 154us/step
# Accuracy:  0.8098159432411194

# %%
classifier.save('CNN.h5')

# %%
import cv2                             
import numpy as np                           #importing libraries
cap = cv2.VideoCapture(0)                #creating camera object
while( cap.isOpened() ) :
    ret,img = cap.read()                         #reading the frames
    cv2.imshow('input',img)                  #displaying the frames
    k = cv2.waitKey(10)
    if k == 27:
        break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-6788252a33f5> in <module>
# ----> 1 import cv2
#       2 import numpy as np                           #importing libraries
#       3 cap = cv2.VideoCapture(0)                #creating camera object
#       4 while( cap.isOpened() ) :
#       5     ret,img = cap.read()                         #reading the frames
#
# ModuleNotFoundError: No module named 'cv2'

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray,(5,5),0)
ret,thresh1 = cv2.threshold(blur,70,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
